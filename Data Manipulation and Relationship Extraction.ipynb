# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx

import matplotlib.pyplot as plt

# %%
# English Language Model download
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 55.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in ./lib/python3.10/site-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.3.0)
# Requirement already satisfied: jinja2 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in ./lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lib/python3.10/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English languague model
model_path = './lib/python3.10/site-packages/en_core_web_sm/en_core_web_sm-3.6.0/'
NER = spacy.load(model_path)

# %% [markdown]
# ## Load book data

# %%
import os

# Get all books from data folder by scan directory function of OS
books = [b for b in os.scandir('Data') if 'txt' in b.name]

# %%
# Display all books we have
books
# Out:
# [<DirEntry '03. Frank Herbert - Children of Dune.txt'>,
#  <DirEntry '01. Frank Herbert - Dune.txt'>,
#  <DirEntry '02. Frank Herbert - Dune Messiah.txt'>]

# %% [markdown]
# Basically, we have 3 books here.

# %%
# Check the first book
book_text_1 = open(books[1], encoding='ISO-8859-1').read()
# Set the limit
NER.max_length = 2000000
# Extract the Entity
book_doc_1 = NER(book_text_1)

# %%
# Visualize identified entities
displacy.render(book_doc_1[0:1000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dune
# Frank Herbert
#
# Copyright
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1965
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br><br>Book
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# <br>DUNE<br><br>= = = = = = <br><br>A beginning is the time for taking the most delicate care that the balances are correct. This every sister of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bene Gesserit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  knows. To begin your study of the life of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Muad'Dib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , then, take care that you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  place him in his time: born in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 57th year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Padishah Emperor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shaddam IV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . And take the most special care that you locate
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Muad'Dib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in his place: the planet
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arrakis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Do not be deceived by the fact that he was born on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Caladan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and lived
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     his first fifteen years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  there.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arrakis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the planet known as
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dune
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , is forever his place.<br>-from &quot;Manual of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Muad'Dib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot; by the Princess Irulan<br><br>    In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  before their departure to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arrakis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , when all the final scurrying about had reached a nearly unbearable frenzy, an old crone came to visit the mother of the boy,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .<br>    It was a warm night at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Castle Caladan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , and the ancient pile of stone that had served the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Atreides
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  family as home for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     twenty-six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  generations bore that cooled-sweat feeling it acquired before a change in the weather.<br>    The old woman was let in by the side door down the vaulted passage by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-r

# %%
# Get all entities by sentence
sentence_df = []

for sent in book_doc_1.sents:
    ent_list = [ent.text for ent in sent.ents]
    sentence_df.append({"sentence": sent, "entity": ent_list})

# %%
# Convert to dataframe
sentence_df = pd.DataFrame(sentence_df)
# Display the df
sentence_df.head()
# Out:
#                                             sentence  \
# 0  (Dune, \n, Frank, Herbert, \n\n, Copyright, 19...
# 1  (A, beginning, is, the, time, for, taking, the...
# 2  (This, every, sister, of, the, Bene, Gesserit,...
# 3  (To, begin, your, study, of, the, life, of, Mu...
# 4  (And, take, the, most, special, care, that, yo...
#
#                                               entity
# 0        [Dune\nFrank Herbert\n\nCopyright, 1965, 1]
# 1                                                 []
# 2                                    [Bene Gesserit]
# 3  [Muad'Dib, first, the 57th year, the Padishah ...
# 4                                [Muad'Dib, Arrakis]

# %% [markdown]
# ## Load character name

# %%
# Read characters
character_df = pd.read_excel("Data/Character.xlsx")

# %%
# Split the character to first name
character_df["first_name"] = character_df["Character"].apply( lambda x: x.split(" ",1)[0])

# %%
# Display
character_df
# Out:
#              Character   first_name
# 0         Lady Jessica         Lady
# 1        Paul Atreides         Paul
# 2      Leto I Atreides         Leto
# 3   Vladimir Harkonnen     Vladimir
# 4                Chani        Chani
# 5              Stilgar      Stilgar
# 6   Gaius Helen Mohiam        Gaius
# 7         Duncan Idaho       Duncan
# 8      Wellington Yueh   Wellington
# 9       Gurney Halleck       Gurney
# 10         Feyd-Rautha  Feyd-Rautha
# 11       Glossu Rabban       Glossu
# 12     Princess Irulan     Princess
# 13          Shaddam IV      Shaddam
# 14        Thufir Hawat       Thufir
# 15       Count Fenring        Count
# 16      Margot Fenring       Margot
# 17      Piter De Vries        Piter
# 18       Alia Atreides         Alia
# 19       Shadout Mapes      Shadout
# 20          Liet-Kynes   Liet-Kynes
# 21             Ramallo      Ramallo
# 22               Jamis        Jamis
# 23               Harah        Harah
# 24              Otheym       Otheym
# 25               Korba        Korba
# 26            Aramsham     Aramsham
# 27         Iakin Nefud        Iakin
# 28             Scytale      Scytale
# 29               Edric        Edric
# 30               Bijaz        Bijaz
# 31              Lichna       Lichna
# 32               Farok        Farok
# 33            Wensicia     Wensicia
# 34    Leto II Atreides         Leto
# 35    Ghanima Atreides      Ghanima
# 36            Tyekanik     Tyekanik
# 37             Farad'n      Farad'n
# 38               Javid        Javid

# %% [markdown]
# ## Data Processing

# %%
# Filter out None Character rows from the data
def filter_out(entity_col, character_df):
    return [x for x in entity_col if x in list(character_df['first_name'])]

# Apply the function to
sentence_df['character_entity'] = sentence_df['entity'].apply(lambda x: filter_out(x, character_df))

# %%
sentence_df.head()
# Out:
#                                             sentence  \
# 0  (Dune, \n, Frank, Herbert, \n\n, Copyright, 19...
# 1  (A, beginning, is, the, time, for, taking, the...
# 2  (This, every, sister, of, the, Bene, Gesserit,...
# 3  (To, begin, your, study, of, the, life, of, Mu...
# 4  (And, take, the, most, special, care, that, yo...
#
#                                               entity character_entity
# 0        [Dune\nFrank Herbert\n\nCopyright, 1965, 1]               []
# 1                                                 []               []
# 2                                    [Bene Gesserit]               []
# 3  [Muad'Dib, first, the 57th year, the Padishah ...               []
# 4                                [Muad'Dib, Arrakis]               []

# %%
# Remove empty observations
df_filtered = sentence_df[sentence_df['character_entity'].apply(lambda x: len(x) > 0)].reset_index()

# %%
df_filtered.head()
# Out:
#    index                                           sentence  \
# 0      8  (In, the, week, before, their, departure, to, ...
# 1     10  (The, old, woman, was, let, in, by, the, side,...
# 2     16  (Paul, 's, mother, answered, in, her, soft, co...
# 3     26  (Within, the, shadows, of, his, bed, ,, Paul, ...
# 4     31  (Paul, lay, awake, wondering, :, What, 's, a, ...
#
#                       entity character_entity
# 0  [the week, Arrakis, Paul]           [Paul]
# 1                     [Paul]           [Paul]
# 2           [Paul, Atreides]           [Paul]
# 3                     [Paul]           [Paul]
# 4                [Paul, gom]           [Paul]

# %% [markdown]
# ## Create Relationship
# ### 1. Loop through window size to extract the relationship

# %%
# Window size (a number of senctences) to extract the relationship
window_size = 5

# Create an empty list to store the combined character_entities
char_list = []

# Iterate through rolling windows of the DataFrame
for window in df_filtered['character_entity'].rolling(window=window_size):
    if window.size == window_size:
        char_list.extend(sum(window.dropna(), []))

# %%
char_list[:10]
# Out:
# ['Paul',
#  'Paul',
#  'Paul',
#  'Paul',
#  'Paul',
#  'Paul',
#  'Paul',
#  'Paul',
#  'Paul',
#  'Paul']

# %% [markdown]
# ### 2. Keep the unique character in sequence

# %%
# Keep only Unique list of character relationship
# Initialize a list to store unique elements
unique_list = []

# Initialize a variable to store the previous element
prev_element = None

# Iterate through char_list
for element in char_list:
    # Check if the current element is different from the previous one
    if element != prev_element:
        unique_list.append(element)
    # Update the previous element
    prev_element = element

# %%
unique_list[:10]
# Out:
# ['Paul',
#  'Piter',
#  'Paul',
#  'Piter',
#  'Feyd-Rautha',
#  'Paul',
#  'Piter',
#  'Feyd-Rautha',
#  'Piter',
#  'Paul']

# %% [markdown]
# ### 3. Build relationship direction

# %%
# Initialize 2 list
source = []
target = []

# Iterate through all elements of the list
for i in range(len(unique_list)-1):
    # Check if the current element is different from the previous one
    source.append(unique_list[i])
    target.append(unique_list[i+1])       

# Create a dataframe of this relationship direction
relationship_df = pd.DataFrame({"Source" : source,
                               "Target" : target})

# %%
# Display
relationship_df.head()
# Out:
#         Source       Target
# 0         Paul        Piter
# 1        Piter         Paul
# 2         Paul        Piter
# 3        Piter  Feyd-Rautha
# 4  Feyd-Rautha         Paul

# %% [markdown]
# ### 4. Create relationship weight

# %%
# Sort the cases with a->b and b->a
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df
# Out:
#            Source    Target
# 0            Paul     Piter
# 1            Paul     Piter
# 2            Paul     Piter
# 3     Feyd-Rautha     Piter
# 4     Feyd-Rautha      Paul
# ...           ...       ...
# 7598   Liet-Kynes  Vladimir
# 7599         Paul  Vladimir
# 7600   Liet-Kynes      Paul
# 7601   Liet-Kynes  Vladimir
# 7602         Paul  Vladimir
#
# [7603 rows x 2 columns]

# %%
# Set weight equal to 1 for each row
relationship_df["Weight"] = 1
# Aggregate data to create weight
relationship_df = relationship_df.groupby(["Source","Target"], sort=False, as_index=False).sum()

# %%
relationship_df.sort_values(by = 'Weight', 
                            ascending = False)
# Out:
#     Source      Target  Weight
# 22    Paul     Stilgar    2060
# 5   Gurney        Paul    1250
# 30   Jamis        Paul     506
# 31   Chani        Paul     472
# 11    Leto        Paul     385
# ..     ...         ...     ...
# 66    Leto      Otheym       1
# 41   Count        Paul       1
# 68  Gurney      Otheym       1
# 26    Lady      Thufir       1
# 38   Jamis  Liet-Kynes       1
#
# [74 rows x 3 columns]

# %%
# Save data into a file
relationship_df.to_csv("relationship_df.csv", index=False)
